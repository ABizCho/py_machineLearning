# %% [markdown]
# # Basic Python

# %% [markdown]
# 출처 : https://colab.research.google.com/drive/1VJWC3nRngHoAQdIe60ZK-gbidHc6okzN
#
# Python is a general purpose programming language. It's an open source software and free.
#
# Please note that this is not meant to be a comprehensive overview of Python in general. If you have no programming experience, you should probably want to take an extra time learning the basics of Python by taking MOOC courses or reading Python books. I would recommend a MOOC site, [Datacamp](https://www.datacamp.com/home). It's very interactive and offers easy-to-follow courses.
#
# This notebook will just go through the basic topics in order:
#
# * Data types
#     * Numbers
#     * Strings
#     * Lists
#     * Dictionaries
# * List comprehension
# * if, elif, else Statements
# * for Loops
# * functions

# %% [markdown]
# ## Data types
#
# ### Numbers
# ### We can do basic calculations with numbers

# %% [markdown]
# #### + addition: add values on either side of the operator

# %%
1+1
# Out:
# 2

# %% [markdown]
# #### * multiplication: multiplies values on either side of the operator

# %%
1 * 3
# Out:
# 3

# %% [markdown]
# #### / divide: divides left hand operand by right hand operand

# %%
1 / 2
# Out:
# 0.5

# %% [markdown]
# #### ** exponent: performs exponential (power) calculation on operators

# %%
2 ** 4
# Out:
# 16

# %%
(2+3)*(5+6)
# Out:
# 55

# %% [markdown]
# ### Variable is a specific, case-sensitive name. call up value through variable name
# ### Variable Assignment

# %% [markdown]
# * Can not start with number or special characters.
# * Assignment uses = and comparison ==.
# * The first assignment to a variable creates it.
#     * Variable types don’t need to be declared.
#     * Python figures out the variable types on its own.

# %%
name_of_var = 2

# %%
x = 2
y = 3

z=x+y

# %%
z
# Out:
# 5

# %% [markdown]
# #### type: you can check out the data type

# %%
type(z)
# Out:
# int

# %%
type(5.0)
# Out:
# float

# %% [markdown]
# ### Strings
#  Can use “” or ‘’ to specify

# %%
'single quotes'
# Out:
# 'single quotes'

# %% [markdown]
# Get a slice of a string.

# %%
s='hello'

# %%
s[4]
# Out:
# 'o'

# %%
s[:3]
# Out:
# 'hel'

# %%
s[1:]
# Out:
# 'ello'

# %% [markdown]
# #### Question: From the following sentence, extract 'there' and 'Sam!' (Poll 1)
#
# s = "Hi there Sam!"

# %% [markdown]
# ### Lists
# * mutable ordered sequence of items of mixed types
# * List are defined using square brackets (and commas).
# * We can access individual members of a tuple, list, or string using square bracket “array” notation.

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['hi',1,[1,2]]
# Out:
# ['hi', 1, [1, 2]]

# %%
my_list = ['a','b','c']

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list=my_list+['d'] # add elements
                      # or my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list.pop(0) # remove elements
my_list
# Out:
# ['b', 'c', 'd']

# %%
my_list[1]='e' # changing list elements
my_list
# Out:
# ['b', 'e', 'd']

# %%
nest = [1,2,3,[4,5,['target']]]

# %%
nest[3]
# Out:
# [4, 5, ['target']]

# %%
nest[3][2]

# %%
nest[3][2][0]

# %% [markdown]
# ### list comprehension
# * [expression for name in list if condition]
# * Generate a new list by applying a function to every member of an original list.
# * The filter condition can be omitted.

# %%
x = [1,2,3,4]

# %%
[item**2 for item in x]
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# #### Question: Use list comprehension to get the output from the following list. (Poll 2)

# %%
li = [('a', 1), ('b', 2), ('c', 7)]

# %%
# Out:
# [('a', 1), ('b', 2), ('c', 7)]

# %% [markdown]
# #### Question: Use list comprehension to get the output from the following list.

# %%
strings=['as','bat','a', 'car','dove','python']

# %%
# Out:
# ['as', 'bat', 'a', 'car', 'dove', 'python']

# %% [markdown]
# ### Dictionaries
# * Dictionaries store a mapping between a set of keys and a set of values
#     * Keys can be any immutable type.
#     * Values can be any type.
#     * A single dictionary can store values of different types.
# * You can define, modify, view, lookup, and delete the key-value pairs in the dictionary.

# %%
d = {'user':'bozo','pwd':1234}

# %%
d
# Out:
# {'pwd': 1234, 'user': 'bozo'}

# %%
d['user']
# Out:
# 'bozo'

# %%
d['id']=45
d
# Out:
# {'id': 45, 'pwd': 1234, 'user': 'bozo'}

# %%
d={'user':'bozo', 'p':1234, 'id':34}
d.keys() # list of keys
# Out:
# dict_keys(['user', 'p', 'id'])

# %%
d.values() # list of values
# Out:
# dict_values(['bozo', 1234, 34])

# %% [markdown]
# ** Given this nest dictionary grab the word "hello". Be prepared, this will
#
# ---
#
# be annoying/tricky **

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d['k1']
# Out:
# [1,
#  2,
#  3,
#  {'tricky': ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]}]

# %% [markdown]
# ### if,elif, else Statements
# * Use of indentation for blocks
# * Colon (:) after boolean expression

# %%
if 1 < 2:
    print('Yep!')
# Out:
# Yep!

# %%
if 1 < 2:
    print('first')
else:
    print('last')
# Out:
# first

# %%
if 1 > 2:
    print('first')
else:
    print('last')
# Out:
# last

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')
# Out:
# middle

# %% [markdown]
# ### for Loops
# * For-each is Python’s only form of for loop.
# * A for loop steps through each of the items in a collection type, or any other type of object which is “iterable”.
#
#     for <item> in <collection>:
#          <statements>
# * If <collection> is a list or a tuple, then the loop steps through each element of the sequence.
# * If <collection> is a string, then the loop steps through each character of the string.

# %% [markdown]
# #### Loop over a list

# %%
seq = [1,2,3,4,5]

# %%
for item in seq:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for item in seq:
    print('Yep')
# Out:
# Yep
# Yep
# Yep
# Yep
# Yep

# %%
for jelly in seq:
    print(jelly+jelly)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# #### Question: Write a code to have the required output from the following list (Poll 3)

# %%
fam = [1.73, 1.68, 1.71, 1.89]

# %%
# Out:
# person 0: 1.73
# person 1: 1.68
# person 2: 1.71
# person 3: 1.89

# %% [markdown]
# #### Loop over list of lists

# %%
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]

# %%
for a in house:
    print("the {} is {} sqm".format(a[0],a[1]))
# Out:
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %% [markdown]
# #### Loop over dictionary

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'austria':'vienna' }

# %%
for key, value in europe.items():
    print("the capital of {} is {}".format(key,value))
# Out:
# the capital of spain is madrid
# the capital of france is paris
# the capital of germany is berlin
# the capital of norway is oslo
# the capital of italy is rome
# the capital of poland is warsaw
# the capital of austria is vienna

# %% [markdown]
# ### functions
# * Function is a piece of reusable code and solves a particular task.
# * There are many built-in functions in Python for standard tasks like type().
# * Call function instead of writing code yourself.

# %%
fam = [1.73, 1.68, 1.71, 1.89]
fam
# Out:
# [1.73, 1.68, 1.71, 1.89]

# %%
max(fam) # get a maximum value
# Out:
# 1.89

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %% [markdown]
# #### How to find functions?
# If it's a standard task, a function probably exists. You can just google it.

# %% [markdown]
# #### Create your own functions
# * But, you can also have your own functions.
# * def creates a function and assigns it a name.
# * return sends a result back to the caller.
# * arguments are passed by the assignment.
# * arguments and return types are not declared.

# %%
def my_func(param1='default'):
    print(param1)

# %%
my_func('new param')
# Out:
# new param

# %%
def square(x):
    return x**2

# %% [markdown]
# Note: the difference between 'print' and 'return': print does not return a value while return returns a value which can be used in following tasks.

# %%
out=square(2)
out
# Out:
# 4

# %% [markdown]
# **You are driving a little too fast, and a police officer stops you. Write a function
#   to return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket".
#   If your speed is 60 or less, the result is "No Ticket". If speed is between 61
#   and 80 inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big    Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of the function) -- on your birthday, your speed can be 5 higher in all
#   cases. **

# %%
# Out:
# 'Small Ticket'

# %%
# Out:
# 'Big Ticket'

# %% [markdown]
# #### Methods
# Methods are functions that belong to ojbects such as int, floating number, string, list, numpy array, etc. In python, everything is an object. In our example above, 'append' is a method that belongs to the list object. Different objects have different methods associated. To call a method, you used a . notation.
#
# string methods: https://www.w3schools.com/python/python_ref_string.asp

# %% [markdown]
# # Great Job!
